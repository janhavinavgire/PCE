# %% [markdown]
# <a href="https://colab.research.google.com/github/janhavinavgire/PCE/blob/main/Assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Enter the value of design speed: 60
Enter the value of Radius of curvature: 200
Enter the value of slope: 140
Enter the value of width of road including extra widening: 7
'enter the value for plain terain:0.08
The value of Super elevation: 0.08
0.08
The length of transition curve: 39.2

# %%
#JANHAVI NAVGIR 22CV069
P =float (input(" Load in kg: "))
p =float (input (" Tyre pressure kg/cm^2: "))
M = int (input ("Total Number of layers in a given Pavement : "))
pi = 3.14159
CBR = []
for i in range (1, M+1):
  print ("California Bearing Ratio of Material in %")
  CBR_value = float (input ())
  CBR. append (CBR_value)
  T = ((1.75*P)/ (CBR_value) -(P/(p*pi)) ) **0.5
  print ("Thickness Above this layer: ", T, "cm")

print ("Given that bitumen layer of 4 cm")
